# %%
#Install Packages
# !pip install faiss-cpu voyageai pandas

# %%
# import necessary libraries
import pandas as pd
pd.set_option('display.max_colwidth', 100)

# %%
df = pd.read_csv("sample_text.csv")
df

# %% [markdown]
# ## STEP 1

# %% [markdown]
# Step 1 : Create source embeddings for the text column

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %%
import torch
print(torch.__version__)

# %%
from sentence_transformers import SentenceTransformer
encoder = SentenceTransformer("all-mpnet-base-v2")
print("Working!")

# %%
import voyageai
import numpy as np

vo = voyageai.Client(api_key="your-voyage-api-key")

result = vo.embed(df.text.tolist(), model="voyage-2")
vectors = np.array(result.embeddings)

vectors.shape  # should show (8, 1024)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import voyageai
#       2 import numpy as np
#       4 vo = voyageai.Client(api_key="your-voyage-api-key")
#
# File ~\anaconda3\Lib\site-packages\voyageai\__init__.py:28
#      20 VOYAGE_EMBED_DEFAULT_MODEL = "voyage-2"
#      22 from voyageai.api_resources import (
#      23     ContextualizedEmbedding,
#      24     Embedding,
#      25     MultimodalEmbedding,
#      26     Reranking,
#      27 )
# ---> 28 from voyageai.chunking import default_chunk_fn
#      29 from voyageai.client import Client
#      30 from voyageai.client_async import AsyncClient
#
# File ~\anaconda3\Lib\site-packages\voyageai\chunking.py:4
#       1 from itertools import chain
#       2 from typing import Callable, List
# ----> 4 from langchain_text_splitters import RecursiveCharacterTextSplitter
# ...

# %%
dim = vectors.shape[1]
dim

# %% [markdown]
# ## Step 2 : Build a FAISS Index for vectors

# %%
import faiss

index = faiss.IndexFlatL2(dim)

# %% [markdown]
# ## Step 3 : Normalize the source vectors (as we are using L2 distance to measure similarity) and add to the index

# %%
index.add(vectors.astype('float32'))
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 index.add(vectors)
#       2 index
#
# NameError: name 'index' is not defined

# %% [markdown]
# ## Step 4 : Encode search text using same encorder and normalize the output vector

# %%
search_query = "I want to buy a polo t-shirt"
# search_query = "looking for places to visit during the holidays"
# search_query = "An apple a day keeps the doctor away"

search_result = vo.embed([search_query], model="voyage-2")
vec = np.array(search_result.embeddings[0])
vec.shape

# %%
svec = np.array(vec).reshape(1, -1).astype('float32')
svec.shape  # should show (1, 1024)

# %% [markdown]
# # Step 5: Search for similar vector in the FAISS index created

# %%
distances, I = index.search(new_vec, k=2)
distances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 distances, I = index.search(new_vec, k=2)
#       2 distances
#
# NameError: name 'index' is not defined

# %%
I

# %%
I.tolist()

# %%
row_indices = I.tolist()[0]
row_indices

# %%
df.loc[row_indices]

# %%
search_query
